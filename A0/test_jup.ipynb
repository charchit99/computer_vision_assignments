# %% [markdown]
# ## CS7.505: Computer Vision
# **Assignment 0: OpenCV and Chroma Keying**
# Name: Charchit Gupta
# Roll: 2019102034

# %%
# Importing all necessary libraries
import cv2
import os
import numpy as np
from PIL import Image 
from matplotlib import pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# **Question 1**
# Video ↔ Images: Write a program to convert a given video to its constituent images. Your output should be
# in a specified folder. Write another program that will merge a set of images in a folder into a single video. You
# should be able to control the frame rate in the video that is created.

# %%
DIR_NAME = 'Frame_Q1'
NUM_OF_FRAMES = 0
# Read the video from specified path
cam = cv2.VideoCapture("originalVideo.mp4")


# Creating directory while the frames from the video will be added -
if not os.path.exists(DIR_NAME):
    os.makedirs(DIR_NAME)
  
# frame
currentframe = 0
  
while(True):
      
    # reading from frame
    ret,frame = cam.read()
  
    if ret:
        # if video is still left continue creating images
        name = './' + DIR_NAME + '/frame' + str(currentframe) + '.jpg'
        print ('Creating...' + name)
  
        # writing the extracted images
        cv2.imwrite(name, frame)
  
        # increasing counter so that it will
        # show how many frames are created
        currentframe += 1
    else:
        break

NUM_OF_FRAMES = currentframe
  
# Release all space and windows once done
cam.release()
cv2.destroyAllWindows()
# Out:
# Creating..../Frame_Q1/frame0.jpg
# Creating..../Frame_Q1/frame1.jpg
# Creating..../Frame_Q1/frame2.jpg
# Creating..../Frame_Q1/frame3.jpg
# Creating..../Frame_Q1/frame4.jpg
# Creating..../Frame_Q1/frame5.jpg
# Creating..../Frame_Q1/frame6.jpg
# Creating..../Frame_Q1/frame7.jpg
# Creating..../Frame_Q1/frame8.jpg
# Creating..../Frame_Q1/frame9.jpg
# Creating..../Frame_Q1/frame10.jpg
# Creating..../Frame_Q1/frame11.jpg
# Creating..../Frame_Q1/frame12.jpg
# Creating..../Frame_Q1/frame13.jpg
# Creating..../Frame_Q1/frame14.jpg
# Creating..../Frame_Q1/frame15.jpg
# Creating..../Frame_Q1/frame16.jpg
# Creating..../Frame_Q1/frame17.jpg
# Creating..../Frame_Q1/frame18.jpg
# Creating..../Frame_Q1/frame19.jpg
# Creating..../Frame_Q1/frame20.jpg
# Creating..../Frame_Q1/frame21.jpg
# Creating..../Frame_Q1/frame22.jpg
# Creating..../Frame_Q1/frame23.jpg
# Creating..../Frame_Q1/frame24.jpg
# Creating..../Frame_Q1/frame25.jpg
# Creating..../Frame_Q1/frame26.jpg
# Creating..../Frame_Q1/frame27.jpg
# ...

# %%
def FramesToVideo(FramesPath, VideoPath, Fps):
    frames = []

    for i in range(NUM_OF_FRAMES):
        filePath = FramesPath + 'frame' + str(i) + '.jpg'
        img = cv2.imread(filePath)
        height, width, layers = img.shape
        size = (width, height)
        print('Inserting' + filePath + '...')
        frames.append(img)
    newVideo = cv2.VideoWriter(VideoPath, cv2.VideoWriter_fourcc(*'DIVX'), Fps, size)
    for i in range(len(frames)):
        newVideo.write(frames[i])
    newVideo.release()

FPS = 60
frame_path = './' + DIR_NAME + '/'
video_path = 'newVideo_' + str(FPS) + 'fps.avi'

FramesToVideo(frame_path, video_path, FPS)
# Out:
# Inserting./Frame_Q1/frame0.jpg...
# Inserting./Frame_Q1/frame1.jpg...
# Inserting./Frame_Q1/frame2.jpg...
# Inserting./Frame_Q1/frame3.jpg...
# Inserting./Frame_Q1/frame4.jpg...
# Inserting./Frame_Q1/frame5.jpg...
# Inserting./Frame_Q1/frame6.jpg...
# Inserting./Frame_Q1/frame7.jpg...
# Inserting./Frame_Q1/frame8.jpg...
# Inserting./Frame_Q1/frame9.jpg...
# Inserting./Frame_Q1/frame10.jpg...
# Inserting./Frame_Q1/frame11.jpg...
# Inserting./Frame_Q1/frame12.jpg...
# Inserting./Frame_Q1/frame13.jpg...
# Inserting./Frame_Q1/frame14.jpg...
# Inserting./Frame_Q1/frame15.jpg...
# Inserting./Frame_Q1/frame16.jpg...
# Inserting./Frame_Q1/frame17.jpg...
# Inserting./Frame_Q1/frame18.jpg...
# Inserting./Frame_Q1/frame19.jpg...
# Inserting./Frame_Q1/frame20.jpg...
# Inserting./Frame_Q1/frame21.jpg...
# Inserting./Frame_Q1/frame22.jpg...
# Inserting./Frame_Q1/frame23.jpg...
# Inserting./Frame_Q1/frame24.jpg...
# Inserting./Frame_Q1/frame25.jpg...
# Inserting./Frame_Q1/frame26.jpg...
# ...

# %% [markdown]
# **Observations**
# We can clearly notice that when we drop the frame rate from 38 (original frame rate) to 10 frames/sec, the video length increase from 3 secs to 11.4 secs. The video seems particularly similar to the 'slow motion' videos captured from phones and the maths for the total number of frames works out too.
#
# $38 * 3 = 10 * 11.4$
#
# The same case repeats for when we change the fps from 38 to 60, here the video length changes from 3 to 1.9 secs.
#
# $38 * 3 = 60 * 1.9$
#
# Having a frame rate lower than the frame rate of the original video made the new video slower and hence of more duration then the original video. Whereas, having a frame rate higher than the frame rate of the original video made the new video faster and hence of lesser duration then the original video.

# %% [markdown]
# *Sample Images*-

# %%
img = mpimg.imread('./Frame_Q1/frame0.jpg')
imgplot = plt.imshow(img)
plt.show()

# %%
img = mpimg.imread('./Frame_Q1/frame30.jpg')
imgplot = plt.imshow(img)
plt.show()

# %%
img = mpimg.imread('./Frame_Q1/frame60.jpg')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# **Question 2**
# Capturing Images: Learn how to capture frames from a webcam connected to your computer and save them as
# images in a folder. You may use either the built-in camera of your laptop or an external one connected through
# USB. You should also be able to display the frames (the video) on the screen while capturing.

# %%
# The following code block was run as a separate python file.

# import the opencv library
import cv2
import os


DIR_NAME2 = 'Frame_Q2'
NUM_OF_FRAMES2 = 0
# Read the video from specified path
cam = cv2.VideoCapture(0)


# Creating directory while the frames from the video will be added
if not os.path.exists(DIR_NAME2):
    os.makedirs(DIR_NAME2)

Begin = True

if not (cam.isOpened()):
    print("Could not open the webcam!")
    Begin = False
  
# frame
currentframe = 0
  
while(Begin):
      
    # reading from frame
    ret,frame = cam.read()
  
    if ret:
        # if video is still left continue creating images
        name = './' + DIR_NAME2 + '/frame' + str(currentframe) + '.jpg'
        print ('Creating...' + name)
  
        # writing the extracted images
        cv2.imwrite(name, frame)
        cv2.imshow('preview', frame)
  
        # increasing counter so that it will
        # show how many frames are created
        currentframe += 1
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break


NUM_OF_FRAMES2 = currentframe
  
# Release all space and windows once done
cam.release()
cv2.destroyAllWindows()

# %%
img = mpimg.imread('Frame_Q2/frame10.jpg')
imgplot = plt.imshow(img)
plt.show()

# %%
img = mpimg.imread('Frame_Q2/frame35.jpg')
imgplot = plt.imshow(img)
plt.show()

# %%
img = mpimg.imread('Frame_Q2/frame60.jpg')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# **Explanations**
# The `opencv` library has an inbuilt function called `VideoCapture` which lets it save a video from the webcam or from an address. If we pass an file address in the parameter, we get the video from that location directly, and if we put `0` there, our webcam instantly turns on and starts recording. The command `cv2.waitkey(x)` displays a window for x millisecs and then destroys the window. The condition `0xFF == ord('q')` makes sure that if the key `q` is pressed the video recording stops and gets saved. The command `cv2.imwrite(name, frame)` saves the frame at the path address *name* and the command *`cv2.imshow('preview', frame)` displays the frame while capturing*.

# %% [markdown]
# **Question 3**
# Chroma Keying: Create an interesting composite of two videos using this technique, possibly with one video including yourselves.

# %% [markdown]
# For this question, we had to use two videos, and via chroma keying we had to add foreground of
# one video as a backgrund on another image. I attempted this problem twice and my challenges
# have been explained below:
#
# 1. In the first attempt, I used a 7 second duration at 30 FPS video, and another video of
# me shot on my phone which was roughly 5 seconds long at 90 FPS. Hence both videos
# had unequal frames (7x30 and 5x90 respectively). I masked pixels of image from my video with RGB values in the
# range [150, 160, 160] to [255, 255, 255]. This range was found by logical trial and error since the
# background in my video was white. After this, I added it to the background image from the
# second video. However, it was very noticiable that both the videos were not in sync at all.
# My video was going very slow compared to the background, and this was beacuse two videos
# of unequal frame rates were being played at the same FPS.
# 2. In the second attempt, I preproccesed my video, so now it was roughly 7 seconds long at
# 38 FPS. I performed by preprocessing by converting the video to frames, and then converting
# it back to a video by choosing 1 in every 4 frames. I did this since I wanted to bring the FPS
# of my video closer to the background video. Rest of the procedure was carried in the same way as before
# and this time both the videos were in sync.

# %%
video = cv2.VideoCapture("Q3_video.mov")
backgroundVideo = cv2.VideoCapture("bg.mp4")

DIR_NAME3 = 'Frame_Q3'
currentframe = 0

if not os.path.exists(DIR_NAME3):
    os.makedirs(DIR_NAME3)

while True:
 
    ret, frame = video.read()
    ret_, image = backgroundVideo.read()

    if ret is False or ret_ is False:
        break
 
    frame = cv2.resize(frame, (640, 480))
    image = cv2.resize(image, (640, 480))

    #print(frame[0, 0], frame[0, 1], frame[0, 2], frame[2][2], frame[3][3], frame[0][300], frame[0][-1])
    #print(frame[-1, 0], frame[-2, 0], frame[-1, 1], frame[-3, 3])

 
    u_green = np.array([104, 153, 70])
    l_green = np.array([30, 30, 0])

    u_white = np.array([255, 255, 255])
    l_white = np.array([150, 160, 160])

    u_white_tight = np.array([255, 255, 255])
    l_white_tight = np.array([130, 150, 150])
 
    mask = cv2.inRange(frame, l_white_tight, u_white_tight)
    # All frame pixels whose rgb values fall in the u_green and l_green range will be replaced by image pixels.

    res = cv2.bitwise_and(frame, frame, mask = mask)

    f = frame - res
    f = np.where(f == 0, image, f)
 
    cv2.imshow("video", frame)
    cv2.imshow("mask", f)

    fileName = './' + DIR_NAME3 + '/frame' + str(currentframe) + '.jpg'
    maskedFileName = './' + DIR_NAME3 + '/maskedFrame' + str(currentframe) + '.jpg'

    currentframe += 1
    
    print ('Creating...' + name)

    # writing the extracted images
    cv2.imwrite(fileName, frame)
    cv2.imwrite(maskedFileName, f)


    if cv2.waitKey(25) == 27:
        break
 
video.release()
cv2.destroyAllWindows()
# Out:
# Creating..../Frame_Q1/frame113.jpg
# Creating..../Frame_Q1/frame113.jpg
# Creating..../Frame_Q1/frame113.jpg
# Creating..../Frame_Q1/frame113.jpg
# Creating..../Frame_Q1/frame113.jpg
# Creating..../Frame_Q1/frame113.jpg
# Creating..../Frame_Q1/frame113.jpg
# Creating..../Frame_Q1/frame113.jpg
# Creating..../Frame_Q1/frame113.jpg
# Creating..../Frame_Q1/frame113.jpg
# Creating..../Frame_Q1/frame113.jpg
# Creating..../Frame_Q1/frame113.jpg
# Creating..../Frame_Q1/frame113.jpg
# Creating..../Frame_Q1/frame113.jpg
# Creating..../Frame_Q1/frame113.jpg
# Creating..../Frame_Q1/frame113.jpg
# Creating..../Frame_Q1/frame113.jpg
# Creating..../Frame_Q1/frame113.jpg
# Creating..../Frame_Q1/frame113.jpg
# Creating..../Frame_Q1/frame113.jpg
# Creating..../Frame_Q1/frame113.jpg
# Creating..../Frame_Q1/frame113.jpg
# Creating..../Frame_Q1/frame113.jpg
# Creating..../Frame_Q1/frame113.jpg
# Creating..../Frame_Q1/frame113.jpg
# Creating..../Frame_Q1/frame113.jpg
# Creating..../Frame_Q1/frame113.jpg
# ...

# %% [markdown]
# **Results**

# %%
img = mpimg.imread('./Frame_Q3/frame0.jpg')
imgplot = plt.imshow(img)
plt.show()

# %%
img = mpimg.imread('./Frame_Q3/maskedFrame0.jpg')
imgplot = plt.imshow(img)
plt.show()

# %%
img = mpimg.imread('./Frame_Q3/frame50.jpg')
imgplot = plt.imshow(img)
plt.show()

# %%
img = mpimg.imread('./Frame_Q3/maskedFrame50.jpg')
imgplot = plt.imshow(img)
plt.show()

# %%
img = mpimg.imread('./Frame_Q3/frame90.jpg')
imgplot = plt.imshow(img)
plt.show()

# %%
img = mpimg.imread('./Frame_Q3/maskedFrame90.jpg')
imgplot = plt.imshow(img)
plt.show()

# %%
img = mpimg.imread('./Frame_Q3/frame130.jpg')
imgplot = plt.imshow(img)
plt.show()

# %%
img = mpimg.imread('./Frame_Q3/maskedFrame130.jpg')
imgplot = plt.imshow(img)
plt.show()

# %%
img = mpimg.imread('./Frame_Q3/frame185.jpg')
imgplot = plt.imshow(img)
plt.show()

# %%
img = mpimg.imread('./Frame_Q3/maskedFrame185.jpg')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# Note: The background is also a video and not an image. The whole video is available on the drive link provided.
